# %% [markdown]
# ## Credit Scoring Classification

# %% [markdown]
# ### Description:
#
# Over the years, the company has collected basic bank details and gathered a lot of credit-related information. The management wants to build an intelligent system to segregate the people into credit score brackets to reduce the manual efforts.

# %% [markdown]
# #### Task:
# Build a machine learning model that can classify the credit score

# %% [markdown]
# ### Step 1: Importing Requirements

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('Dataset/train.csv')
df.head()
# Out:
# C:\Users\MSI 11\AppData\Local\Temp\ipykernel_21604\239670640.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Dataset/train.csv')
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0      19114.12            1824.843333                  3  ...           _
# 1      19114.12                    NaN                  3  ...        Good
# ...

# %% [markdown]
# ### Step 2: Gain Information from Dataset

# %%
print('This dataset have', df.shape[0], 'rows and', df.shape[1], 'columns')
print('Number of integer types: ', df.select_dtypes(include=['int64']).shape[1])
print('Number of object/string types: ', df.select_dtypes(include=['object']).shape[1])
print('Number of decimal types: ', df.select_dtypes(include=['float']).shape[1])
print('Number of boolean types: ', df.select_dtypes(include=['bool']).shape[1])
print('Number of datetime types: ', df.select_dtypes(include=['datetime64']).shape[1])
print('Number of missing data: ', df.isna().sum().sum())
# Out:
# This dataset have 100000 rows and 28 columns
# Number of integer types:  4
# Number of object/string types:  20
# Number of decimal types:  4
# Number of boolean types:  0
# Number of datetime types:  0
# Number of missing data:  60071
